# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, Flatten, Softmax, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from tensorflow.keras.utils import to_categorical
from keras.models import load_model
import random
from tensorflow.keras import backend as K
import torch
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# # **Data process**

# %%
df = open('/kaggle/input/go-competition/29_Training Dataset/Training Dataset/dan_train.csv').read().splitlines()
games = [i.split(',',2)[-1] for i in df]

random.seed(42)
random.shuffle(games)

# %%
games_sorted = sorted(games, key=lambda x: len(x), reverse=True)

# %%
chars = 'abcdefghijklmnopqrs'
coordinates = {k:v for v,k in enumerate(chars)}
chartonumbers = {k:v for k,v in enumerate(chars)}
coordinates
# Out:
# {'a': 0,
#  'b': 1,
#  'c': 2,
#  'd': 3,
#  'e': 4,
#  'f': 5,
#  'g': 6,
#  'h': 7,
#  'i': 8,
#  'j': 9,
#  'k': 10,
#  'l': 11,
#  'm': 12,
#  'n': 13,
#  'o': 14,
#  'p': 15,
#  'q': 16,
#  'r': 17,
#  's': 18}

# %%
def prepare_input(moves):
    x = np.zeros((19,19,3))
    for move in moves:
        color = move[0]
        column = coordinates[move[2]]
        row = coordinates[move[3]]
        if color == 'B':
            x[row,column,0] = 1
            #x[row,column,2] = 1
        if color == 'W':
            x[row,column,1] = 1
            #x[row,column,2] = 1
    if moves:
        last_move_column = coordinates[moves[-1][2]]
        last_move_row = coordinates[moves[-1][3]]
        x[row,column,2] = 1
    #x[:,:,2] = np.where(x[:,:,2] == 0, 1, 0)
    return x

def prepare_label(move):
    column = coordinates[move[2]]
    row = coordinates[move[3]]
    return column*19+row

# %%
# Check how many samples can be obtained
n_games = 0
n_moves = 0
for game in games:
    n_games += 1
    moves_list = game.split(',')
    for move in moves_list:
        n_moves += 1
print(f"Total Games: {n_games}, Total Moves: {n_moves}")
# Out:
# Total Games: 100160, Total Moves: 22853380

# %%
import random

random_sample = random.sample(games, 500)

# %% [markdown]
# x = []
# y = []
# x1 = []
# y1 = []
# for game in random_sample:
#         x1 = prepare_input_Zero1(game)
#         x.extend(x1)
#         y1 = prepare_label_Zero1(game)
#         y.extend(y1)
# x = np.array(x)
# y = np.array(y)
# y_one_hot = tf.one_hot(y, depth=19*19)

# %%
x = []
y = []
for game in games_sorted[:500]:
    moves_list = game.split(',')
    for count, move in enumerate(moves_list):
        x.append(prepare_input(moves_list[:count]))
        y.append(prepare_label(moves_list[count]))
x = np.array(x)
y = np.array(y)

y_one_hot = tf.one_hot(y, depth=19*19)

# %%
x.shape
# Out:
# (171704, 19, 19, 3)

# %%
y.shape
# Out:
# (171704,)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_one_hot.numpy(), test_size=0.05)

# %%
def residual_block(x, num_filters):
    # 保存輸入，用於殘差連接
    shortcut = x
    shortcut = Conv2D(num_filters, kernel_size=3, padding='same')(shortcut)
    # 第一個卷積層
    x = Conv2D(num_filters, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    # 第二個卷積層
    x = Conv2D(num_filters, kernel_size=3, padding='same')(x)
    # 殘差連接
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def residual_1(x, num_filters):
    # 保存輸入，用於殘差連接
    shortcut = x
    
    # 第一個卷積層
    x = Conv2D(num_filters, kernel_size=1, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters/2, kernel_size=1, padding='same')(x)
    x = Activation('relu')(x)
    # 第二個卷積層
    x = Conv2D(num_filters, kernel_size=1, padding='same')(x)
    # 殘差連接
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def create_model():
    inputs = keras.Input(shape=(19, 19, 3))
    x = inputs

    outputs = Conv2D(kernel_size=3, filters=128, padding='same', activation='relu')(x)

    for _ in range(6):  # 您可以根據需要調整殘差塊的數量
        outputs = residual_block(outputs, num_filters=128)
    outputs = residual_1(outputs,128)
    
    for _ in range(6):  # 您可以根據需要調整殘差塊的數量
        outputs = residual_block(outputs, num_filters=128)
    outputs = residual_1(outputs,128)
    
    outputs = Conv2D(kernel_size=1, filters=1, padding='same', activation='relu')(outputs)
    outputs = Flatten()(outputs)
    outputs = Softmax()(outputs)
    model = Model(inputs, outputs)
    
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
from tensorflow.keras import mixed_precision
strategy = tf.distribute.MirroredStrategy()
mixed_precision.set_global_policy('mixed_float16')

from tensorflow.keras.optimizers.schedules import ExponentialDecay

initial_learning_rate = 0.000006
min_learning_rate = 0.000001
decay_steps = 5000
decay_rate = 0.9

lr_schedule = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate,
    staircase=True
)


with strategy.scope():
    #model = create_model()
    # Load the pre-trained model
    model = load_model('/kaggle/input/model-for-train-in-public/model_dan_testv2_6times_0.5288.h5', compile=False)

    # Define the new optimizer
    new_optimizer =  Adam(learning_rate=lr_schedule)
    new_optimizer = mixed_precision.LossScaleOptimizer(new_optimizer)
    # Compile the model with the new optimizer
    model.compile(optimizer=new_optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    model.trainable = False
# Display the model summary after recompiling
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 19, 19, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 128)  3584        ['input_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 128)  147584      ['conv2d_1[0][0]']
#
#  activation (Activation)        (None, 19, 19, 128)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 128)  147584      ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 19, 19, 128)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 128)  147584      ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 128)  147584      ['conv2d_1[0][0]']
#
#  add (Add)                      (None, 19, 19, 128)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_2 (Activation)      (None, 19, 19, 128)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 128)  147584      ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 19, 19, 128)  0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 128)  147584      ['activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 19, 19, 128)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 128)  147584      ['activation_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 128)  147584      ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 19, 19, 128)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  activation_5 (Activation)      (None, 19, 19, 128)  0           ['add_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 19, 19, 128)  0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 19, 19, 128)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_5[0][0]']
#
#  add_2 (Add)                    (None, 19, 19, 128)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_8 (Activation)      (None, 19, 19, 128)  0           ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 19, 19, 128)  0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 19, 19, 128)  0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_10[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_8[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 128)  0           ['conv2d_17[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_11 (Activation)     (None, 19, 19, 128)  0           ['add_3[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 19, 19, 128)  0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 19, 19, 128)  0           ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_13[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_11[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 128)  0           ['conv2d_21[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_14 (Activation)     (None, 19, 19, 128)  0           ['add_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 19, 19, 128)  0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 19, 19, 128)  0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_14[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 128)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  activation_17 (Activation)     (None, 19, 19, 128)  0           ['add_5[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 19, 19, 128)  16512       ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 19, 19, 128)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 19, 19, 64)   8256        ['activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 19, 19, 64)   0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 19, 19, 128)  8320        ['activation_19[0][0]']
#
#  add_6 (Add)                    (None, 19, 19, 128)  0           ['conv2d_28[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_20 (Activation)     (None, 19, 19, 128)  0           ['add_6[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 19, 19, 128)  0           ['conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 19, 19, 128)  0           ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_22[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_20[0][0]']
#
#  add_7 (Add)                    (None, 19, 19, 128)  0           ['conv2d_32[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  activation_23 (Activation)     (None, 19, 19, 128)  0           ['add_7[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_23[0][0]']
#
#  activation_24 (Activation)     (None, 19, 19, 128)  0           ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 19, 19, 128)  0           ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_25[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_23[0][0]']
#
#  add_8 (Add)                    (None, 19, 19, 128)  0           ['conv2d_36[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  activation_26 (Activation)     (None, 19, 19, 128)  0           ['add_8[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 19, 19, 128)  0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 19, 19, 128)  0           ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_28[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_26[0][0]']
#
#  add_9 (Add)                    (None, 19, 19, 128)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  activation_29 (Activation)     (None, 19, 19, 128)  0           ['add_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_29[0][0]']
#
#  activation_30 (Activation)     (None, 19, 19, 128)  0           ['conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 19, 19, 128)  0           ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_29[0][0]']
#
#  add_10 (Add)                   (None, 19, 19, 128)  0           ['conv2d_44[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  activation_32 (Activation)     (None, 19, 19, 128)  0           ['add_10[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_32[0][0]']
#
#  activation_33 (Activation)     (None, 19, 19, 128)  0           ['conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_33[0][0]']
#
#  activation_34 (Activation)     (None, 19, 19, 128)  0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_34[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_32[0][0]']
#
#  add_11 (Add)                   (None, 19, 19, 128)  0           ['conv2d_48[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  activation_35 (Activation)     (None, 19, 19, 128)  0           ['add_11[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_35[0][0]']
#
#  activation_36 (Activation)     (None, 19, 19, 128)  0           ['conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 19, 19, 128)  0           ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_37[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 19, 19, 128)  147584      ['activation_35[0][0]']
#
#  add_12 (Add)                   (None, 19, 19, 128)  0           ['conv2d_52[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  activation_38 (Activation)     (None, 19, 19, 128)  0           ['add_12[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 19, 19, 128)  16512       ['activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 19, 19, 128)  0           ['conv2d_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 19, 19, 64)   8256        ['activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 19, 19, 64)   0           ['conv2d_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 19, 19, 128)  8320        ['activation_40[0][0]']
#
#  add_13 (Add)                   (None, 19, 19, 128)  0           ['conv2d_55[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_41 (Activation)     (None, 19, 19, 128)  0           ['add_13[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 19, 19, 1)    129         ['activation_41[0][0]']
#
#  flatten (Flatten)              (None, 361)          0           ['conv2d_56[0][0]']
#
#  softmax (Softmax)              (None, 361)          0           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 7,153,921
# Trainable params: 0
# Non-trainable params: 7,153,921
# __________________________________________________________________________________________________

# %%
#from tensorflow.keras.callbacks import EarlyStopping
#
#early_stopping = EarlyStopping(
#    monitor='val_loss', 
#    patience=5,           
#    restore_best_weights=True,  
#)

#history = model.fit(
#    x = x_train, 
#    y = y_train,
#    batch_size = 128,
#    epochs = 50,
#    validation_data=(x_val, y_val),
#    callbacks=[early_stopping],
#)

# %%
from tensorflow.keras.utils import Sequence
import multiprocessing

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
    # Define your custom data generator class
class MyDataGenerator(Sequence):
    def __init__(self, games, batch_size):
        self.games = games
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.games) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_games = self.games[start:end]

        x, y_one_hot = data_pocess(batch_games)
        indices = np.random.permutation(len(x))
        x = x[indices]
        y_one_hot = y_one_hot[indices]
        return x, y_one_hot

# %%
def data_pocess(batch_games):
    with strategy.scope():
        x = []
        y = []
        for game in batch_games:
            moves_list = game.split(',')
            game_x = []
            game_y = []
            for count, move in enumerate(moves_list):
                game_x.append(prepare_input(moves_list[:count]))
                game_y.append(prepare_label(moves_list[count]))
            x.extend(game_x)
            y.extend(game_y)
        x = np.array(x)
        y = np.array(y)
        y_one_hot = tf.one_hot(y, depth=19 * 19)
        return x , y_one_hot.numpy()

# %%
x_train =  games_sorted[40000:70000] 
x_val =  random_sample 

x_train = np.array(x_train)
x_val = np.array(x_val)

random.shuffle(x_train)
random.shuffle(x_val)

# %%
print("model_dan_testv2_7times")
# Out:
# model_dan_testv2_7times

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

model_checkpoint = ModelCheckpoint(
    filepath='model_dan_testv2_7times.h5',  
    save_best_only=True,  
    verbose=1  
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an instance of the data generator
batch_size = 8
data_generator_train = MyDataGenerator(x_train, batch_size)
data_generator_val = MyDataGenerator(x_val, batch_size)

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=2,          
    restore_best_weights=True, 
)

# Train your model using the data generator
history = model.fit(
    data_generator_train,
    epochs=8,
    validation_data=data_generator_val,
    callbacks=[model_checkpoint, early_stopping],
    workers = 2
)
# Out:
# Epoch 1/8
#   13/3750 [..............................] - ETA: 5:51:33 - loss: 1.7112 - accuracy: 0.5272

# %%
model.save('./model_dan_testv2_7times.h5')
